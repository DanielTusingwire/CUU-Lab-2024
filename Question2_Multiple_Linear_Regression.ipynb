# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielTusingwire/CUU-Lab-2024/blob/main/Question2_Multiple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **QUESTION 2**
# a) Produce a multiple Linear regression graph regards Serious, Fatal and Minor. (10 marks)
#
# b) Determine the coefficients and intercept values of your graph. (5 marks)
#
# c) State the multiple linear regression model mathematically. (5 marks)
#
# d) Evaluate the model by obtaining the values of R-squared and mean square errors. (5 marks)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/drive/MyDrive/SIMULATION_FINAL/Risk_Factors.csv")
data
# Out:
#      Year  Fatal  Serious  Minor           Risk_Factor  Total_Crashes
# 0    2020   1081     2611   1666  Population Behaviour           5358
# 1    2019    835     2587   1740  Population Behaviour           5162
# 2    2018    830     2698   2013  Population Behaviour           5541
# 3    2017    720     2951   2027  Population Behaviour           5698
# 4    2016    710     3245   2612  Population Behaviour           6567
# ..    ...    ...      ...    ...                   ...            ...
# 125  2015    625      960   1396      Road environment           2981
# 126  2014    703      990   1292      Road environment           2985
# 127  2013    585     1008   1302      Road environment           2895
# 128  2012    621     1108   1242      Road environment           2971
# 129  2011    371      564    643      Road environment           1578
#
# [130 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(data)
df
# Out:
#      Year  Fatal  Serious  Minor           Risk_Factor  Total_Crashes
# 0    2020   1081     2611   1666  Population Behaviour           5358
# 1    2019    835     2587   1740  Population Behaviour           5162
# 2    2018    830     2698   2013  Population Behaviour           5541
# 3    2017    720     2951   2027  Population Behaviour           5698
# 4    2016    710     3245   2612  Population Behaviour           6567
# ..    ...    ...      ...    ...                   ...            ...
# 125  2015    625      960   1396      Road environment           2981
# 126  2014    703      990   1292      Road environment           2985
# 127  2013    585     1008   1302      Road environment           2895
# 128  2012    621     1108   1242      Road environment           2971
# 129  2011    371      564    643      Road environment           1578
#
# [130 rows x 6 columns]

# %%
# extracting the predictor variables and the target variable

X = df[['Serious', 'Fatal', 'Minor']]  # Independent variables
y = df['Total_Crashes']

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression


model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
import seaborn as sns

width = 10
height = 5
plt.figure(figsize=(width, height))

ax1 = sns.distplot(y, hist=False, color='r', label='Actual values')
sns.distplot(y_pred, hist=False, color='g', label='Predicted values', ax=ax1)

plt.title('Actual values vs Predicted values for Total Crushes')
plt.xlabel('Actual Values (Serious, Fatal, Minor)')
plt.ylabel('predicted values for Total Crushes')
plt.legend()


plt.show()
plt.close()
# Out:
# <ipython-input-15-af86078e5308>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(y, hist=False, color='r', label='Actual values')
# <ipython-input-15-af86078e5308>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # **b) Determine the coefficients and intercept values of your graph**

# %%
intercept = model.intercept_
coeff = model.coef_

print("Intercept:", intercept)
print("Coefficients :", coeff)
# Out:
# Intercept: 2.2737367544323206e-13
# Coefficients : [1. 1. 1.]

# %% [markdown]
# # **c) State the multiple linear regression model mathematically. (5 marks)**

# %% [markdown]
# # **d) Evaluate the model by obtaining the values of R-squared and mean squared errors**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# Model performance on training data
r_squared = r2_score(y, y_pred)

mse = mean_squared_error(y, y_pred)
print("\nModel Performance Metrics:")
print("R-squared:", r_squared)
print("Mean Squared Error:", mse)
# Out:
# Model Performance Metrics:
# R-squared: 1.0
# Mean Squared Error: 2.589235034924376e-25
